# %%
## A terminer

# %% [markdown]
# A simple example
# ================
#
# To illustrate how *pyKasso* can be used, let us start with a simple example. <br>
# The aim is to generate a stochastic karstic network from scratch.
#
#
# Let's start!
# ------------
#
# First, we have to import the *pyKasso* module:

# %%
import pykasso as pk
#import agd
#agd.Eikonal.LibraryCall.binary_dir['FileHFM']='path/to/FileHFM/bin'
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-627419624bc1> in <module>
# ----> 1 import pykasso as pk
#       2 #import agd
#       3 #agd.Eikonal.LibraryCall.binary_dir['FileHFM']='path/to/FileHFM/bin'
#
# ~\Anaconda3\lib\site-packages\pykasso\__init__.py in <module>
#       3 from pykasso.geologymanager import *
#       4 from pykasso.pointmanager   import *
# ----> 5 from pykasso.sks            import *
#
# ~\Anaconda3\lib\site-packages\pykasso\sks.py in <module>
#      42 from .geologymanager import GeologyManager
#      43 from .pointmanager   import PointManager
# ---> 44 from .karstnetwork   import KarstNetwork
#      45 from .functions      import get_settings
#      46
#
# ImportError: cannot import name 'KarstNetwork' from 'pykasso.karstnetwork' (C:\Users\mivillef\Anaconda3\lib\site-packages\pykasso\karstnetwork.py)

# %% [markdown]
# Then, we create an instance of the `SKS` class. If no argument is given, *pyKasso* will use the default settings file. <br>
# Here, the `rand_seed` argument is used in order to guarantee the reproducibility of the example:

# %%
catchment = pk.SKS()
catchment = pk.SKS(rand_seed=1)

# %% [markdown]
# Visualize the generated environment
# -----------------------------------
#
# Once the ``SKS`` class is constructed, it contains now all the geological data.
# With this default configuration, only the fractures and inlets positions are stochastically generated. <br>
# We can access to the geological data with the ``get`` functions, or we can print it out with the ``show_cacthment()`` method.

# %%
# Return a numpy-array
geology   = catchment.get_geology()
faults    = catchment.get_faults()
fractures = catchment.get_fractures()

# Print out directly the requested data
catchment.show_catchment(data='geology')
catchment.show_catchment(data='faults')
catchment.show_catchment(data='fractures')

# %% [markdown]
# Compute a karst network
# -----------------------
#
# To start a stochastic karst network simulation, simply use the ``compute_karst_network()`` method:

# %%
catchment.set_outlets_importance([1])
catchment.set_inlets_importance([1])
catchment.set_inlets_per_outlet([1])
catchment.compute_karst_network()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-313bef343d74> in <module>
#       2 catchment.set_inlets_importance([1])
#       3 catchment.set_inlets_per_outlet([1])
# ----> 4 catchment.compute_karst_network()
#
# ~\Anaconda3\lib\site-packages\pykasso\sks.py in compute_karst_network(self, verbose)
#    1311
#    1312         # Step 1 - Initialize the parameters
# -> 1313         self._initialize_karst_network_parameters()
#    1314
#    1315         # Step 2 - Compute conduits for each generation & store nodes and edges for network
#
# ~\Anaconda3\lib\site-packages\pykasso\sks.py in _initialize_karst_network_parameters(self)
#    1353         self.nbr_iteration   = len(self.settings['outlets_importance'])*len(self.settings['inlets_importance']) #total number of iterations that will occur
#    1354         outlets_repartition  = self._repartition_points(self.outlets, self.settings['outlets_importance']) #correct for outlets_importance not summing to correct number of actual outlets
# -> 1355         self.outlets         = self._distribute_outlets(outlets_repartition)  # distribute outlets to iterations
#    1356         inlets_repartition   = self._repartition_points(self.inlets, self.settings['inlets_per_outlet']) #correct for inlets_per_outlet not summing to correct number of actual inlets
#    1357         self.inlets          = self._distribute_inlets(inlets_repartition)  # distribute inlets to outlets
#
# ~\Anaconda3\lib\site-packages\pykasso\sks.py in _distribute_outlets(self, repartition)
#    1421         for k,n in enumerate(repartition):        #get iteration index and number of points being assigned to that iteration
#    1422             for j in range(n):                    #loop over each point in current iteration
# -> 1423                 outlets.append((self.outlets[i][0], self.outlets[i][1], k))   #append point with its iteration number
#    1424                 i += 1                                                                #increment point index by 1
#    1425         return np.asarray(outlets)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 0

# %% [markdown]
# The print out above come from the *karstnet* dependance and is, at this stage, not relevant. <br>
# Once the calculations are over, the results are stored in a ``KarstNetwork`` object then piled-up in a ``SKS`` list. <br>
# A ``KarstNetwork`` object store several useful data from a simulation in different attributes:
# - ``maps`` : the maps calculated by *pyKasso*
# - ``points`` : the positions of the inlets and outlets
# - ``network`` : the positions of each node from the network and the associated bounds
# - ``stats`` : the statistics calculated by *karstnet*
# - ``settings`` : the settings used from the simulation

# %%
catchment.karst_simulations

# %%
catchment.karst_simulations[0].__dict__.keys()
# Out:
# dict_keys(['maps', 'points', 'network', 'stats', 'settings'])

# %%
catchment.show()

# %%
# catchment.compare_stats()
# Error ?  Why ?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-9c050f1d57d9> in <module>
# ----> 1 catchment.compare_stats()
#
# ~\anaconda3\envs\agd-hfm\lib\site-packages\pykasso\sks.py in compare_stats(self, data, mean)
#    1968         for karst_network in self.karst_simulations[i:]:
#    1969             stats_list = []
# -> 1970             stats_list.append(karst_network.stats['cpd'])
#    1971             stats_list.append(karst_network.stats['cv degree'])
#    1972             stats_list.append(karst_network.stats['cv length'])
#
# KeyError: 'cpd'
