# %%
import pykasso as pk
import matplotlib
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Exemple 1

# %%
catchment = pk.SKS('inputs/tsanfleuron598x789.yaml') 
catchment.set_parameter('faults_mode', 'csv')  
catchment.update_feature('faults')
# Out:
# CAUTION: You are using the development version of this package.
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 19749/19749 [00:01<00:00, 11397.38it/s]

# %%
catchment = pk.SKS('inputs/tsanfleuron598x789.yaml') 
catchment.set_parameter('orientation_mode', 'surface')                       
catchment.update_feature('orientation') 
catchment.set_parameter('algorithm', 'Riemann2')
# Out:
# CAUTION: You are using the development version of this package.
# - inspect_polygon() - WARNING : 2/108 vertices not inside the grid limits.
# - vertex 0 : (582751.9819, 129254.6915)
# - vertex 107 : (582754.7321, 130467.3852)
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 20067/20067 [00:01<00:00, 11794.34it/s]

# %%
#geology     = catchment.get_feature('geology')
#topography  = catchment.get_feature('topography')
surface      = catchment.get_feature('surface')
faults      = catchment.get_feature('faults')
fractures   = catchment.get_feature('fractures')
mask = catchment.get_feature('mask')

# %%
faults
# Out:
# ID : 5 | Type : faults | Shape : (789, 598, 1) | Mode : null

# %%
f = catchment.show_catchment(data_key='faults')
#f.set_size_inches(20,20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-4f4d097052b4> in <module>
#       1 f = catchment.show_catchment(data_key='faults')
#       2 #f.set_size_inches(20,20)
# ----> 3 f.plt
#
# AttributeError: 'Figure' object has no attribute 'plt'

# %%
catchment.show_catchment()

# %%
faults
# Out:
# ID : 5 | Type : faults | Shape : (789, 598, 1) | Mode : null

# %%
catchment.compute_karst_network()
# Out:
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd

# %%
catchment.compute_karst_network()
f = catchment.show_network()
# Out:
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# C:\Users\measdaya\Anaconda3\envs\pykasso\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
f.savefig('test.png',dpi=300)

# %% [markdown]
# ## Exemple 2

# %%
tsanfleuron = pk.SKS('inputs/tsanfleuron598x789.yaml')
# Out:
# CAUTION: You are using the development version of this package.
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 19940/19940 [00:01<00:00, 11415.39it/s]

# %%
for data in ["geology", "faults", "fractures", "orientationx", "orientationy"]:
    tsanfleuron.show_catchment(data)
# Out:
# no data for indicated data_key parameter
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-5-200557b5d3e7> in <module>
#       1 for data in ["geology", "faults", "fractures", "orientationx", "orientationy"]:
# ----> 2     tsanfleuron.show_catchment(data)
#
# ~\Anaconda3\envs\pykasso\lib\site-packages\pykasso\sks.py in show_catchment(self, data_key, title, cmap)
#     901             print('no data for indicated data_key parameter')
#     902
# --> 903         im1 = ax1.imshow(data.T, origin="lower", extent=self.grid.extent, cmap=cmap)
#     904
#     905         fig.colorbar(im1, ax=ax1)
#
# UnboundLocalError: local variable 'data' referenced before assignment

# %%
tsanfleuron.compute_karst_network()
tsanfleuron.show()

for i in range(10):
    tsanfleuron.update_feature('fractures')
    tsanfleuron.set_parameter('outlets_mode', 'random') 
    tsanfleuron.set_parameter('outlets_number', 1) 
    tsanfleuron.set_parameter('inlets_mode', 'composite') 
    tsanfleuron.set_parameter('inlets_number', 100) 
    tsanfleuron.update_feature('inlets')
    tsanfleuron.update_feature('outlets')
    tsanfleuron.compute_karst_network()
    tsanfleuron.show()
# Out:
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 20199/20199 [00:01<00:00, 11063.01it/s]
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 19877/19877 [00:01<00:00, 10714.15it/s]
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 20167/20167 [00:01<00:00, 11359.65it/s]
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 19888/19888 [00:01<00:00, 11295.98it/s]
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 20021/20021 [00:01<00:00, 11147.41it/s]
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 20237/20237 [00:01<00:00, 10982.28it/s]
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 20277/20277 [00:01<00:00, 10908.11it/s]
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 19939/19939 [00:01<00:00, 11092.71it/s]
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 19796/19796 [00:01<00:00, 11336.02it/s]
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 20324/20324 [00:01<00:00, 10643.20it/s]
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd

# %% [markdown]
# ## Exemple Chloé

# %%
catchment = pk.SKS('inputs/tsanfleuron598x789.yaml') 
#catchment.set_parameter('data_has_mask', True)                             
#catchment.update_feature('mask')
catchment.set_parameter('orientation_mode', 'surface')                       
catchment.update_feature('orientation')                  
catchment.compute_karst_network()
f = catchment.show()
# Out:
# CAUTION: You are using the development version of this package.
# Rasterizing: 100%|████████████████████████████████████████████████████████████| 20127/20127 [00:01<00:00, 11094.97it/s]
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
