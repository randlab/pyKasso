# %%
import pykasso as pk

# %%
# First create grid object
x0, y0 ,z0 = 0, 0, 0
nx, ny, nz = 100, 100, 5
dx, dy, dz = 10, 10, 10

grid = pk.Grid(x0,y0,z0,nx,ny,nz,dx,dy,dz)

# %%
# Then create geology manager
geology = pk.GeologyManager(grid)

# %%
# Set "geology", "faults" and "fractures" data
geology.set_data_null("geology")

# %%
# Fracture generation settings
fractures_densities = [0.00001]
alpha = [2]
fractures_min_orientation = [130]
fractures_max_orientation = [150]
fractures_min_dip = [80]
fractures_max_dip = [90]
fractures_min_length = [10]
fractures_max_length = [100]

# %%
# Generate fracture
geology.generate_fractures(fractures_densities, alpha, 
                           fractures_min_orientation, fractures_max_orientation,
                           fractures_min_dip,fractures_max_dip,
                           fractures_min_length, fractures_max_length)

# %%
# Fractures are stored in this list
geology.fractures
# Out:
# [[id:0, fam.:0, x:591.18, y:3.14, z:31.98, rad:6.09, or.:2.48, dip.:1.54] ,
#  [id:1, fam.:0, x:117.16, y:172.52, z:4.25, rad:9.13, or.:2.35, dip.:1.52] ,
#  [id:2, fam.:0, x:67.53, y:-32.5, z:57.7, rad:29.88, or.:2.57, dip.:1.53] ,
#  [id:3, fam.:0, x:870.21, y:87.61, z:46.43, rad:9.14, or.:2.36, dip.:1.45] ,
#  [id:4, fam.:0, x:761.86, y:924.22, z:-15.28, rad:5.78, or.:2.26, dip.:1.42] ,
#  [id:5, fam.:0, x:210.79, y:455.65, z:62.16, rad:23.77, or.:2.31, dip.:1.44] ,
#  [id:6, fam.:0, x:193.09, y:983.0, z:44.83, rad:26.09, or.:2.33, dip.:1.45] ,
#  [id:7, fam.:0, x:332.27, y:105.97, z:1.83, rad:8.13, or.:2.47, dip.:1.5] ,
#  [id:8, fam.:0, x:255.18, y:490.23, z:-18.77, rad:12.16, or.:2.51, dip.:1.48] ,
#  [id:9, fam.:0, x:-46.14, y:814.83, z:-5.79, rad:10.62, or.:2.51, dip.:1.46] ,
#  [id:10, fam.:0, x:353.12, y:218.22, z:46.08, rad:9.13, or.:2.33, dip.:1.46] ,
#  [id:11, fam.:0, x:671.0, y:139.46, z:21.5, rad:7.63, or.:2.37, dip.:1.43] ,
#  [id:12, fam.:0, x:155.81, y:686.52, z:-4.22, rad:8.04, or.:2.46, dip.:1.54] ,
#  [id:13, fam.:0, x:460.95, y:624.48, z:48.37, rad:42.81, or.:2.45, dip.:1.4] ,
#  [id:14, fam.:0, x:115.03, y:497.19, z:-29.08, rad:14.83, or.:2.53, dip.:1.49] ,
#  [id:15, fam.:0, x:905.56, y:453.8, z:-17.15, rad:23.7, or.:2.49, dip.:1.44] ,
#  [id:16, fam.:0, x:670.01, y:84.7, z:20.27, rad:43.4, or.:2.58, dip.:1.52] ,
#  [id:17, fam.:0, x:929.95, y:494.29, z:-25.85, rad:11.78, or.:2.55, dip.:1.53] ,
#  [id:18, fam.:0, x:634.68, y:93.33, z:22.26, rad:16.24, or.:2.43, dip.:1.54] ,
#  [id:19, fam.:0, x:1036.93, y:786.19, z:21.37, rad:34.4, or.:2.35, dip.:1.47] ]

# %%
# Visualize fractures
# %matplotlib qt
import pyvista as pv
frac = geology.fractures

p = pv.Plotter()
for f in frac:
    x, y, z = f.get_position()
    a, b, c = f.get_normal()
    print(f.get_normal())
    pol = pv.Polygon(center=(x, y, z), radius=f.radius, normal=(a, b, c), n_sides=12)
    p.add_mesh(pol, color="tan", show_edges=True)
p.show_bounds()

p.show()
# Out:
# [-0.027171998986614394, -0.02135211230800136, -0.9994027065057698]
# [-0.03753979271632897, -0.03816385701119673, -0.9985661139758569]
# [-0.03657738528267165, -0.023521621784590614, -0.9990539666076631]
# [-0.08857447407330882, -0.08819811353976972, -0.9921570718946988]
# [-0.09754260034425359, -0.11860501256357567, -0.9881388020480095]
# [-0.08821816904981707, -0.09612184994559479, -0.9914525427939224]
# [-0.07949585513616612, -0.08390361593841542, -0.9932978366273776]
# [-0.056397323895406026, -0.04519410496916435, -0.9973849982496593]
# [-0.06919729029297446, -0.05112001718966711, -0.9962923661549545]
# [-0.08711607588407658, -0.06318379522585386, -0.9941924347647276]
# [-0.07691876507064467, -0.08183403453144834, -0.9936733338337669]
# [-0.09767127047298228, -0.0957463722671891, -0.9906023193602297]
# [-0.02040662371044811, -0.016477156968127453, -0.9996559773276944]
# [-0.13398531040237804, -0.11162966990377994, -0.9846759636517749]
# [-0.06762627730707009, -0.0472258740386882, -0.9965923958363666]
# [-0.10267596611566045, -0.07793105411871198, -0.991657398896495]
# [-0.04200863243603999, -0.02614035895126234, -0.9987752281843763]
# [-0.03516478574452201, -0.023881696604183426, -0.9990961427264383]
# [-0.022915664696560558, -0.019572683159880512, -0.9995457880384658]
# [-0.07303523778575746, -0.0741797488835925, -0.9945668498885055]
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x2BAE43F78B0>
# [(2245.6432823363366, 2211.6993889037194, 1755.8320602599204),
#  (507.2563934326172, 473.3125, 17.445171356201172),
#  (0.0, 0.0, 1.0)]
