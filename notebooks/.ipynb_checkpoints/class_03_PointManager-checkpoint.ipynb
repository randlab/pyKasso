# %%
import pykasso as pk
import numpy as np

# %%
# First create grid object
x0, y0 ,z0 = 0, 0, 0
nx, ny, nz = 6, 6, 6
dx, dy, dz = 1, 1, 1

grid = pk.Grid(x0,y0,z0,nx,ny,nz,dx,dy,dz)

# %%
# Set a seed (for reproducibility)
seed = 1
np.random.seed(seed)

# %% [markdown]
# ### Without polygon

# %%
# Create an empty polygon
polygon = pk.Polygon(grid)

# %%
# Then create point manager
points = pk.PointManager(grid, polygon)

# %%
# Generate 15 inlets
points.generate_points("inlets", 15)

# %%
# Generate 1 outlet
points.generate_points("outlets", 1)

# %%
# Display points
points.show()

# %% [markdown]
# ### With a polygon

# %%
# Add a polygon
polygon.set_polygon([[3,3],[3,7],[7,7],[7,5]])

# %%
# Generate 15 inlets
points.generate_points("inlets", 15)

# %%
# Generate 1 outlet
points.generate_points("outlets", 1)

# %%
# Display points
points.show()

# %% [markdown]
# ### Set the points manually

# %%
# Set inlets
points.set_points("inlets", [[0,4],[4,4],[4,1],[6,0]])

# %%
# Set outlet
points.set_points("outlets", [[0,0]])

# %%
# Display points
# One inlet is outside the grid
# Two inlet are in the grid but outside the polygon
# The outlet is outside the polygon
points.show()

# %%
# inspect_points() can inspect for us if all points are well in the grid
# Return an error because no outlet is in the polygon
points.inspect_points()
# Out:
# - inspect_points() - Warning : 3 inlets on 4 masked because not inside polygon.
# - point on line 1
# - point on line 3
# - point on line 4
# - inspect_points() - Warning : 1 outlets on 1 masked because not inside polygon.
# - point on line 1
# - inspect_points() - Error : all the "outlets" are outside the domain.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\mivillef\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3425: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# inspect_points() applied a mask on points outside the polygon
points.show()
# Out:
# C:\Users\mivillef\Anaconda3\lib\site-packages\numpy\core\_asarray.py:136: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# ### Remove the polygon

# %%
# Clean polygon
polygon.clean_polygon()

# %%
# Set inlets and outlets again
points.set_points("inlets", [[0,4],[4,4],[4,1],[6,0]])
points.set_points("outlets", [[0,0]])

# %%
# Inspect points again
points.inspect_points()
# Out:
# - inspect_points() - Warning : 1 inlets on 4 masked because not inside polygon.
# - point on line 4

# %%
# Display points
# The point outside the grid has been masked by inspect_points()
points.show()
