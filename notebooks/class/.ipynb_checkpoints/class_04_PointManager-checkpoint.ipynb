# %% [markdown]
# # PointManager class
# This notebook display how the PointManager() class works.

# %%
import pykasso as pk
import numpy as np

# %%
# First create grid object
x0, y0 ,z0 =  0,  0,  0
nx, ny, nz = 10, 10,  1
dx, dy, dz =  1,  1,  1

grid = pk.Grid(x0,y0,z0,nx,ny,nz,dx,dy,dz)

# %%
# Set a seed (for reproducibility)
seed = 1
np.random.seed(seed)

# %% [markdown]
# ### Without polygon

# %%
# Create an empty polygon
polygon = pk.Polygon(grid)
# Then create a point manager
points = pk.PointManager(grid, polygon)

# %%
# Generate 15 inlets
points.generate_points("inlets", 15)
# Generate 1 outlet
points.generate_points("outlets", 1)

# %%
# Display points
points.show()

# %% [markdown]
# ### With a polygon

# %%
# Add a polygon
polygon.set_polygon([[3,3],[3,7],[7,7],[7,5]])

# %%
# Generate 15 inlets
points.generate_points("inlets", 15)
# Generate 1 outlet
points.generate_points("outlets", 1)

# %%
# Display points
points.show()

# %% [markdown]
# ### Set the points manually

# %%
# Set inlets
points.set_points("inlets", [[0,4],[4,4],[4,1],[11,0]])

# %%
# Display points
# One inlet is outside the grid
# Two inlet are in the grid but outside the polygon
# The outlet is outside the polygon
points.show()

# %%
# inspect_points() can inspect for us if all points are well in the grid
# Return an error because no outlet is in the polygon
points.inspect_points()
# Out:
# - inspect_points() - Warning : 3 inlets on 4 masked because not inside polygon.
# - point on line 1
# - point on line 3
# - point on line 4

# %%
# inspect_points() applied a mask on points outside the polygon
points.show()
# Out:
# C:\Users\kiwi\anaconda3\envs\pykasso\lib\site-packages\numpy\core\_asarray.py:171: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# ### Remove the polygon

# %%
# Clean polygon
polygon.clean_polygon()

# %%
# Set inlets and outlets again
points.set_points("inlets", [[0,4],[4,4],[4,1],[6,0]])
points.set_points("outlets", [[0,0]])

# %%
# Inspect points again
points.inspect_points()

# %%
# Display points
# The point outside the grid has been masked by inspect_points()
points.show()

# %% [markdown]
# ### Generate points according to geology

# %%
# Create grid object
x0, y0 ,z0 =   0,   0,  0
nx, ny, nz = 100, 100,  1
dx, dy, dz =   1,   1,  1
grid = pk.Grid(x0,y0,z0,nx,ny,nz,dx,dy,dz)
# Create a polygon
polygon = pk.Polygon(grid)
polygon.set_polygon([[10,10],[90,30],[90,80],[70,90],[0,80]])
# Create a geology
geology = pk.GeologyManager(grid)
geology.set_data_from_image("geology", "inputs/geology.png")
geology.compute_stats_on_data("geology")
# Create a point manager
points = pk.PointManager(grid, polygon, geology)
points.show()

# %%
# Generate 30 inlets in the id=0
points.generate_points("inlets", 30, [0])
# Generate 5 outlets in the id=1
points.generate_points("outlets", 5, [1])
points.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-49a26742252a> in <module>
#       2 points.generate_points("inlets", 30, [0])
#       3 # Generate 5 outlets in the id=1
# ----> 4 points.generate_points("outlets", 5, [1])
#       5 points.show()
#
# ~\anaconda3\envs\pykasso\lib\site-packages\pykasso\pointmanager.py in generate_points(self, points_key, points_number, geological_IDs)
#     108                     y = self.grid.y0 - self.grid.dy/2 + self.grid.ny*np.random.random() * self.grid.dy
#     109                     if self.geology.data["geology"]["data"][self.grid.get_i(x)][self.grid.get_j(y)][0] in new_ids:
# --> 110                         if int(Path(self.polygon.polygon).contains_point((x,y))):
#     111                             rand_x.append(x)
#     112                             rand_y.append(y)
#
# ~\anaconda3\envs\pykasso\lib\site-packages\matplotlib\path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     149         self._codes = codes
#     150         self._interpolation_steps = _interpolation_steps
# --> 151         self._update_values()
#     152
#     153         if readonly:
#
# ~\anaconda3\envs\pykasso\lib\site-packages\matplotlib\path.py in _update_values(self)
#     189
#     190     def _update_values(self):
# --> 191         self._simplify_threshold = mpl.rcParams['path.simplify_threshold']
#     192         self._should_simplify = (
#     193             self._simplify_threshold > 0 and
#
# KeyboardInterrupt:

# %%
print(points.geology.data["geology"]["data"][15,1,0])
print("\n")

for z in range(points.grid.nz):
    for y in range(points.grid.ny):
        for x in range(points.grid.nx):
            print(points.geology.data["geology"]["data"][x,y,z])
        print("\n")

# %%
points.geology.data["geology"]["data"][4,0,0]

# %%
points.points["inlets"]
