# %%
import pykasso as pk
import numpy as np
import agd
agd.Eikonal.LibraryCall.binary_dir['FileHFM']='path/to/FileHFM/bin'

# %%
pk.get_settings(example=True)

# %%
betteraz = pk.SKS('inputs/betteraz_cas_1.yaml')
# Out:
# Rasterizing: 100%|██████████| 1034/1034 [00:03<00:00, 262.64it/s]

# %%
import matplotlib.pyplot as plt
for k in range(betteraz.grid.nz):    
    plt.figure( figsize=(3,3) )
    plt.imshow(betteraz.geology.data['fractures']['data'][k,:,:], origin='lower')
    plt.title('Layer '+str(k))
    plt.axis('off')
    plt.show()

# %%
betteraz.set_outlets_importance([1])
betteraz.set_inlets_importance([1])
betteraz.set_inlets_per_outlet([1])

# %%
betteraz.compute_karst_network()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-6b2bb37fabf2> in <module>
# ----> 1 betteraz.compute_karst_network()
#
# ...

# %%
betteraz.show()
